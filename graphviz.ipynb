# %%
from graphviz import Digraph

# %%
dot = Digraph()
dot.node('1')
dot.node('2')
dot.attr('node', shape='egg', color='green')
dot.node('3')
dot.attr('node', color='red')
dot.node('4')
dot.edges(['12', '23', '24'])
dot
